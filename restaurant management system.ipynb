# %%
x="placed order"
print("Starter","Main_course","Dessert","Drinks")
x=input("select your food category")
starter=["Potato Wedges","French Fries","Garlic Bread","Panner tikka","Chicken tikka","Spring rolls","Veg Manchurian"]
for item in starter:
        print(item)
starter_price={
     "Potato Wedges":100,
     "French Fries":120,
     "Garlic Bread":80,
     "Paneer tikka":150,
     "Chicken tikka":200,
     "Spring rolls":90,
     "Veg Manchurian":110
}
starter=input("select your starter")
starter_quantity=int(input("enter the quantity"))
print("price of selected starter:",starter_price[starter]*starter_quantity)
main_course=["Butter Naan","Tandoori Roti","Plain Naan","Lachha Paratha","Veg Biryani","Chicken Biryani"]
for item in main_course:
    print(item)
main_course_price={
       "Butter Naan":20,
       "Tandoori Roti":15,
       "Plain Naan":10,
       "Lachha Paratha":25,
       "Veg Biryani":150,   
       "Chicken Biryani":200
}
main_course=input("select your main course:")
main_course_quantity=int(input("enter the quantity"))
print("price of selected main course:",main_course_price[main_course]*main_course_quantity)
dessert=["Gulab Jamun","Rasmalai","Ice Cream","Kheer"]
for item in dessert:
    print(item)
dessert_price={
       "Gulab Jamun":50,
       "Rasmalai":60,
       "Ice Cream":80,
       "Kheer":70
}
dessert=input("select your dessert:")
dessert_quantity=int(input("enter the quantity"))
print("price of selected dessert:",dessert_price[dessert]*dessert_quantity)
drinks=["Coke","Pepsi","Sprite","Fanta"]
for item in drinks:
    print(item)
drinks_price={
       "Coke":30,
       "Pepsi":30,
       "Sprite":30,
       "Fanta":30
}
drinks=input("select your drinks:")
drinks_quantity=int(input("enter the quantity"))
print("price of selected drinks:",drinks_price[drinks]*drinks_quantity)
total_bill=(
    starter_price[starter]*
starter_quantity
    +main_course_price[main_course]*
main_course_quantity+
      dessert_price[dessert]*
dessert_quantity 
    + drinks_price[drinks]*drinks_quantity
)

print(f"total_price:{total_bill}")
# Out:
# Starter Main_course Dessert Drinks
# select your food category starter
# Potato Wedges
# French Fries
# Garlic Bread
# Panner tikka
# Chicken tikka
# Spring rolls
# Veg Manchurian
# select your starter Chicken tikka
# enter the quantity 4
# price of selected starter: 800
# Butter Naan
# Tandoori Roti
# Plain Naan
# Lachha Paratha
# Veg Biryani
# Chicken Biryani
# select your main course: Chicken Biryani
# enter the quantity 4
# price of selected main course: 800
# Gulab Jamun
# Rasmalai
# Ice Cream
# Kheer
# select your dessert: Gulab Jamun
# enter the quantity 4
# price of selected dessert: 200
# Coke
# Pepsi
# Sprite
# Fanta
# select your drinks: Coke
# enter the quantity 4
# price of selected drinks: 120
# total_price:1920
